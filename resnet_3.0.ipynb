# %% [markdown]
# # Initialize

# %%
import numpy as np
import torch
from matplotlib import pyplot as plt
from torch import nn
from torch.utils.data import DataLoader
from torchsummary import summary

from utils.dataset import EEGDataset
from prepare_data import get_raw_dataloader, get_sub1_dataloader, get_frequency_dataloader, get_time_series_dataloader
from utils.training import best_torch_device, train

# %%
# torch.manual_seed(3407)
torch.manual_seed(0)
np.random.seed(0)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Constants

# %%
DEVICE = best_torch_device()
RAW = "raw"
SUB1 = "sub1"
FREQ = "frequency"

# %% [markdown]
# ## Load Data

# %%
train_data = {}
valid_data = {}
test_data = {}

# %% [markdown]
# ### Raw Data

# %%
train_data[RAW], valid_data[RAW], test_data[RAW] = get_raw_dataloader()

# %%
print("Training set shape:", train_data[RAW].dataset.X.shape)
print("Validation set shape:", valid_data[RAW].dataset.X.shape)
print("Test set shape:", test_data[RAW].dataset.X.shape)
# Out:
# Training set shape: (1777, 22, 1000)
# Validation set shape: (338, 22, 1000)
# Test set shape: (443, 22, 1000)

# %% [markdown]
# ### Sub1 Data

# %%
X_train_data = np.load('data/X_train_valid.npy')
y_train_data = np.load('data/y_train_valid.npy')
X_test_data = np.load('data/X_test.npy')
y_test_data = np.load('data/y_test.npy')

split_idx = 1777
X_train_data, X_valid_data = X_train_data[:199], X_train_data[1777:1815]
y_train_data, y_valid_data = y_train_data[:199], y_train_data[1777:1815]

test_person = np.load('data/person_test.npy')
sub0_index = (test_person == 0).reshape(-1)
X_test_data = X_test_data[sub0_index]
y_test_data = y_test_data[sub0_index]

train_set = EEGDataset(X_train_data, y_train_data, label_smoothing=True)
valid_set = EEGDataset(X_valid_data, y_valid_data, label_smoothing=False)
test_set = EEGDataset(X_test_data, y_test_data, label_smoothing=False)

train_data[SUB1] = DataLoader(train_set, batch_size=16, shuffle=True)
valid_data[SUB1] = DataLoader(valid_set, batch_size=16, shuffle=False)
test_data[SUB1] = DataLoader(test_set, batch_size=16, shuffle=False)

# %%
print("Training set shape:", X_train_data.shape, y_train_data.shape)
print("Validation set shape:", X_valid_data.shape, y_valid_data.shape)
print("Test set shape:", X_test_data.shape, y_test_data.shape)
# Out:
# Training set shape: (199, 22, 1000) (199,)
# Validation set shape: (38, 22, 1000) (38,)
# Test set shape: (50, 22, 1000) (50,)

# %% [markdown]
# ### Frequency Data

# %%
train_data[FREQ], valid_data[FREQ], test_data[FREQ] = get_frequency_dataloader()

# %%
print("Training set shape:", train_data[FREQ].dataset.X.shape)
print("Validation set shape:", valid_data[FREQ].dataset.X.shape)
print("Test set shape:", test_data[FREQ].dataset.X.shape)
# Out:
# Training set shape: (1777, 22, 1000)
# Validation set shape: (338, 22, 1000)
# Test set shape: (443, 22, 1000)

# %% [markdown]
# # Model

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride = 1, downsample = None):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size = 3, stride = stride, padding = 1)
        self.bn1 = nn.BatchNorm1d(out_channels)
        self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size = 3, stride = 1, padding = 1)
        self.bn2 = nn.BatchNorm1d(out_channels)
        # self.dropout = nn.Dropout(0.2)
        self.downsample = downsample
        self.relu = nn.ReLU()
        self.out_channels = out_channels
        
    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        if self.downsample:
            residual = self.downsample(x)
        out += residual
        out = self.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(ResNet, self).__init__()
        self.initial_conv = nn.Conv1d(in_channels, 64, kernel_size=7, stride=2, padding=3)
        self.bn = nn.BatchNorm1d(64)
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool1d(kernel_size=3, stride=2, padding=1)
        self.layer1 = ResidualBlock(64, 64)
        self.layer2 = ResidualBlock(64, 64)
        # self.layer3 = ResidualBlock(64, 64)
        # self.layer4 = ResidualBlock(64, 64)
        self.avg_pool = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(0.2)
        self.fc = nn.Linear(64, num_classes)

    def forward(self, x):
        x = self.initial_conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.maxpool(x)
        x = self.dropout(x)
        x = self.layer1(x)
        x = self.layer2(x)
        # x = self.dropout(x)
        # x = self.layer3(x)
        # x = self.layer4(x)
        x = self.avg_pool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.fc(x)
        return x

# %%
test_model = ResNet(in_channels=22, num_classes=4)
test_model.forward(torch.rand(2, 22, 1000))
_ = summary(test_model, (22, 1000))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv1d: 1-1                            [-1, 64, 500]             9,920
# ├─BatchNorm1d: 1-2                       [-1, 64, 500]             128
# ├─ReLU: 1-3                              [-1, 64, 500]             --
# ├─MaxPool1d: 1-4                         [-1, 64, 250]             --
# ├─Dropout: 1-5                           [-1, 64, 250]             --
# ├─ResidualBlock: 1-6                     [-1, 64, 250]             --
# |    └─Conv1d: 2-1                       [-1, 64, 250]             12,352
# |    └─BatchNorm1d: 2-2                  [-1, 64, 250]             128
# |    └─ReLU: 2-3                         [-1, 64, 250]             --
# |    └─Conv1d: 2-4                       [-1, 64, 250]             12,352
# |    └─BatchNorm1d: 2-5                  [-1, 64, 250]             128
# |    └─ReLU: 2-6                         [-1, 64, 250]             --
# ├─ResidualBlock: 1-7                     [-1, 64, 250]             --
# |    └─Conv1d: 2-7                       [-1, 64, 250]             12,352
# |    └─BatchNorm1d: 2-8                  [-1, 64, 250]             128
# |    └─ReLU: 2-9                         [-1, 64, 250]             --
# |    └─Conv1d: 2-10                      [-1, 64, 250]             12,352
# |    └─BatchNorm1d: 2-11                 [-1, 64, 250]             128
# |    └─ReLU: 2-12                        [-1, 64, 250]             --
# ├─AdaptiveAvgPool1d: 1-8                 [-1, 64, 1]               --
# ├─Dropout: 1-9                           [-1, 64]                  --
# ├─Linear: 1-10                           [-1, 4]                   260
# ==========================================================================================
# Total params: 60,228
# Trainable params: 60,228
# Non-trainable params: 0
# Total mult-adds (M): 17.27
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 1.46
# Params size (MB): 0.23
# Estimated Total Size (MB): 1.78
# ==========================================================================================

# %% [markdown]
# # Training

# %% [markdown]
# ## Raw Data
# Train on raw data, evaluate on raw data

# %%
raw_model = ResNet(in_channels=22, num_classes=4)
raw_model.to(DEVICE)

optimizer = torch.optim.Adam(raw_model.parameters(), lr=0.001, weight_decay=1e-03)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)

train_loss_hist, train_acc_hist, val_loss_hist, val_acc_hist = train(
    model=raw_model,
    optimizer=optimizer,
    scheduler=scheduler,
    loss_func=nn.CrossEntropyLoss(),
    train_data=train_data[RAW],
    val_data=valid_data[RAW],
    early_stopping_patience=30,
    cp_path="models/resnet",
    cp_filename="raw.pt",
    n_epochs=100,
    show_progress_bar=False,
)
# Out:
# Using device: cpu
# [Epoch 0] val_acc=0.236686 train_acc=0.264491 val_loss=0.024605 train_loss=0.022442
# Validation loss decreased (inf --> 0.024605).  Saving model ...
# [Epoch 1] val_acc=0.251479 train_acc=0.303883 val_loss=0.024717 train_loss=0.021956
# EarlyStopping counter: 1 out of 30
# [Epoch 2] val_acc=0.269231 train_acc=0.330895 val_loss=0.026381 train_loss=0.021682
# EarlyStopping counter: 2 out of 30
# [Epoch 3] val_acc=0.349112 train_acc=0.332020 val_loss=0.023656 train_loss=0.021419
# Validation loss decreased (0.024605 --> 0.023656).  Saving model ...
# [Epoch 4] val_acc=0.242604 train_acc=0.386607 val_loss=0.032028 train_loss=0.020947
# EarlyStopping counter: 1 out of 30
# [Epoch 5] val_acc=0.266272 train_acc=0.397299 val_loss=0.025927 train_loss=0.020650
# EarlyStopping counter: 2 out of 30
# [Epoch 6] val_acc=0.298817 train_acc=0.416432 val_loss=0.025177 train_loss=0.020206
# EarlyStopping counter: 3 out of 30
# [Epoch 7] val_acc=0.328402 train_acc=0.440068 val_loss=0.027137 train_loss=0.019852
# EarlyStopping counter: 4 out of 30
# [Epoch 8] val_acc=0.343195 train_acc=0.464266 val_loss=0.022955 train_loss=0.019718
# Validation loss decreased (0.023656 --> 0.022955).  Saving model ...
# [Epoch 9] val_acc=0.420118 train_acc=0.467642 val_loss=0.021971 train_loss=0.019380
# Validation loss decreased (0.022955 --> 0.021971).  Saving model ...
# [Epoch 10] val_acc=0.467456 train_acc=0.459764 val_loss=0.021326 train_loss=0.019348
# Validation loss decreased (0.021971 --> 0.021326).  Saving model ...
# [Epoch 11] val_acc=0.437870 train_acc=0.478897 val_loss=0.021051 train_loss=0.019088
# Validation loss decreased (0.021326 --> 0.021051).  Saving model ...
# [Epoch 12] val_acc=0.485207 train_acc=0.517164 val_loss=0.020843 train_loss=0.018755
# Validation loss decreased (0.021051 --> 0.020843).  Saving model ...
# [Epoch 13] val_acc=0.458580 train_acc=0.518852 val_loss=0.020567 train_loss=0.018573
# Validation loss decreased (0.020843 --> 0.020567).  Saving model ...
# [Epoch 14] val_acc=0.440828 train_acc=0.538548 val_loss=0.021627 train_loss=0.018448
# EarlyStopping counter: 1 out of 30
# [Epoch 15] val_acc=0.452663 train_acc=0.535172 val_loss=0.021597 train_loss=0.018172
# EarlyStopping counter: 2 out of 30
# [Epoch 16] val_acc=0.470414 train_acc=0.549240 val_loss=0.021396 train_loss=0.018031
# EarlyStopping counter: 3 out of 30
# [Epoch 17] val_acc=0.375740 train_acc=0.576252 val_loss=0.023104 train_loss=0.017758
# EarlyStopping counter: 4 out of 30
# [Epoch 18] val_acc=0.360947 train_acc=0.580191 val_loss=0.024451 train_loss=0.017639
# EarlyStopping counter: 5 out of 30
# [Epoch 19] val_acc=0.479290 train_acc=0.592572 val_loss=0.020161 train_loss=0.017320
# Validation loss decreased (0.020567 --> 0.020161).  Saving model ...
# [Epoch 20] val_acc=0.352071 train_acc=0.581880 val_loss=0.025672 train_loss=0.017469
# EarlyStopping counter: 1 out of 30
# [Epoch 21] val_acc=0.337278 train_acc=0.604389 val_loss=0.026609 train_loss=0.017284
# EarlyStopping counter: 2 out of 30
# [Epoch 22] val_acc=0.334320 train_acc=0.612831 val_loss=0.025859 train_loss=0.016859
# EarlyStopping counter: 3 out of 30
# [Epoch 23] val_acc=0.461538 train_acc=0.613393 val_loss=0.021076 train_loss=0.016685
# EarlyStopping counter: 4 out of 30
# [Epoch 24] val_acc=0.440828 train_acc=0.591446 val_loss=0.022633 train_loss=0.017043
# EarlyStopping counter: 5 out of 30
# [Epoch 25] val_acc=0.467456 train_acc=0.613393 val_loss=0.020112 train_loss=0.016951
# Validation loss decreased (0.020161 --> 0.020112).  Saving model ...
# [Epoch 26] val_acc=0.473373 train_acc=0.631401 val_loss=0.020040 train_loss=0.016422
# Validation loss decreased (0.020112 --> 0.020040).  Saving model ...
# [Epoch 27] val_acc=0.582840 train_acc=0.644907 val_loss=0.017934 train_loss=0.016035
# Validation loss decreased (0.020040 --> 0.017934).  Saving model ...
# [Epoch 28] val_acc=0.443787 train_acc=0.637029 val_loss=0.023359 train_loss=0.016209
# EarlyStopping counter: 1 out of 30
# [Epoch 29] val_acc=0.579882 train_acc=0.634215 val_loss=0.018954 train_loss=0.016323
# EarlyStopping counter: 2 out of 30
# [Epoch 30] val_acc=0.375740 train_acc=0.644344 val_loss=0.026596 train_loss=0.016204
# EarlyStopping counter: 3 out of 30
# [Epoch 31] val_acc=0.470414 train_acc=0.675295 val_loss=0.021149 train_loss=0.015651
# EarlyStopping counter: 4 out of 30
# [Epoch 32] val_acc=0.571006 train_acc=0.644344 val_loss=0.017754 train_loss=0.015824
# Validation loss decreased (0.017934 --> 0.017754).  Saving model ...
# [Epoch 33] val_acc=0.473373 train_acc=0.674170 val_loss=0.020546 train_loss=0.015508
# EarlyStopping counter: 1 out of 30
# [Epoch 34] val_acc=0.520710 train_acc=0.690490 val_loss=0.020540 train_loss=0.015199
# EarlyStopping counter: 2 out of 30
# [Epoch 35] val_acc=0.355030 train_acc=0.714125 val_loss=0.025661 train_loss=0.014867
# EarlyStopping counter: 3 out of 30
# [Epoch 81] val_acc=0.612426 train_acc=0.884637 val_loss=0.016300 train_loss=0.010912
# EarlyStopping counter: 18 out of 30
# [Epoch 82] val_acc=0.591716 train_acc=0.875070 val_loss=0.017045 train_loss=0.011098
# EarlyStopping counter: 19 out of 30
# [Epoch 83] val_acc=0.553254 train_acc=0.907710 val_loss=0.020152 train_loss=0.010611
# EarlyStopping counter: 20 out of 30
# [Epoch 84] val_acc=0.494083 train_acc=0.895892 val_loss=0.022648 train_loss=0.010828
# EarlyStopping counter: 21 out of 30
# [Epoch 85] val_acc=0.603550 train_acc=0.889702 val_loss=0.016923 train_loss=0.010891
# EarlyStopping counter: 22 out of 30
# [Epoch 86] val_acc=0.606509 train_acc=0.878447 val_loss=0.016370 train_loss=0.010857
# EarlyStopping counter: 23 out of 30
# [Epoch 87] val_acc=0.630178 train_acc=0.898706 val_loss=0.016271 train_loss=0.010554
# EarlyStopping counter: 24 out of 30
# [Epoch 88] val_acc=0.573964 train_acc=0.887451 val_loss=0.018113 train_loss=0.010767
# EarlyStopping counter: 25 out of 30
# [Epoch 89] val_acc=0.568047 train_acc=0.898143 val_loss=0.018328 train_loss=0.010590
# EarlyStopping counter: 26 out of 30
# [Epoch 90] val_acc=0.594675 train_acc=0.901519 val_loss=0.017334 train_loss=0.010604
# EarlyStopping counter: 27 out of 30
# [Epoch 91] val_acc=0.600592 train_acc=0.912212 val_loss=0.016714 train_loss=0.010390
# EarlyStopping counter: 28 out of 30
# [Epoch 92] val_acc=0.529586 train_acc=0.916151 val_loss=0.020465 train_loss=0.010285
# EarlyStopping counter: 29 out of 30
# [Epoch 93] val_acc=0.559172 train_acc=0.903770 val_loss=0.017936 train_loss=0.010419
# EarlyStopping counter: 30 out of 30
# Early stopping.

# %%
plt.plot(train_loss_hist, label="Train Loss")
plt.plot(val_loss_hist, label="Val Loss")
plt.title("Raw Data Model Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.plot(train_acc_hist, label="Train Acc")
plt.plot(val_acc_hist, label="Val Acc")
plt.title("Raw Data Model Accuracies")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# Load best model and test
raw_model = torch.load("models/resnet/raw.pt")
raw_model.to(DEVICE)
raw_model.eval()
# Out:
# ResNet(
#   (initial_conv): Conv1d(22, 64, kernel_size=(7,), stride=(2,), padding=(3,))
#   (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (maxpool): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): ResidualBlock(
#     (conv1): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (layer2): ResidualBlock(
#     (conv1): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (avg_pool): AdaptiveAvgPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
# Evaluate on raw data
test_acc = 0
with torch.no_grad():
    for X, y in test_data[RAW]:
        X, y = X.to(DEVICE), y.to(DEVICE)
        y_pred = raw_model(X)
        test_acc += (y_pred.argmax(dim=1) == y.argmax(dim=1)).sum().item()
test_acc /= len(test_data[RAW].dataset)
print("Train on raw data, evaluate on raw data")
print(f"Test Acc: {test_acc:.4f}")
# Out:
# Train on raw data, evaluate on raw data
# Test Acc: 0.6321

# %%
# Evaluate on sub1 data
test_acc = 0
with torch.no_grad():
    for X, y in test_data[SUB1]:
        X, y = X.to(DEVICE), y.to(DEVICE)
        y_pred = raw_model(X)
        test_acc += (y_pred.argmax(dim=1) == y.argmax(dim=1)).sum().item()
test_acc /= len(test_data[SUB1].dataset)
print("Train on raw data, evaluate on sub1 data")
print(f"Test Acc: {test_acc:.4f}")
# Out:
# Train on raw data, evaluate on sub1 data
# Test Acc: 0.5800

# %% [markdown]
# ## Sub1 Data

# %%
sub1_model = ResNet(in_channels=22, num_classes=4)
sub1_model.to(DEVICE)

optimizer = torch.optim.Adam(sub1_model.parameters(), lr=0.0001, weight_decay=0.1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.3, patience=8, verbose=True)

train_loss_hist, train_acc_hist, val_loss_hist, val_acc_hist = train(
    model=sub1_model,
    optimizer=optimizer,
    scheduler=scheduler,
    loss_func=nn.CrossEntropyLoss(),
    train_data=train_data[SUB1],
    val_data=valid_data[SUB1],
    early_stopping_patience=30,
    cp_path="models/resnet",
    cp_filename="sub1.pt",
    n_epochs=80,
    show_progress_bar=False,
)
# Out:
# Using device: cpu
# [Epoch 0] val_acc=0.157895 train_acc=0.236181 val_loss=0.122488 train_loss=0.102874
# Validation loss decreased (inf --> 0.122488).  Saving model ...
# [Epoch 1] val_acc=0.184211 train_acc=0.241206 val_loss=0.118680 train_loss=0.100036
# Validation loss decreased (0.122488 --> 0.118680).  Saving model ...
# [Epoch 2] val_acc=0.236842 train_acc=0.286432 val_loss=0.114830 train_loss=0.094453
# Validation loss decreased (0.118680 --> 0.114830).  Saving model ...
# [Epoch 3] val_acc=0.236842 train_acc=0.180905 val_loss=0.111473 train_loss=0.095264
# Validation loss decreased (0.114830 --> 0.111473).  Saving model ...
# [Epoch 4] val_acc=0.236842 train_acc=0.271357 val_loss=0.109807 train_loss=0.091515
# Validation loss decreased (0.111473 --> 0.109807).  Saving model ...
# [Epoch 5] val_acc=0.263158 train_acc=0.326633 val_loss=0.107779 train_loss=0.089365
# Validation loss decreased (0.109807 --> 0.107779).  Saving model ...
# [Epoch 6] val_acc=0.263158 train_acc=0.271357 val_loss=0.107196 train_loss=0.090687
# Validation loss decreased (0.107779 --> 0.107196).  Saving model ...
# [Epoch 7] val_acc=0.315789 train_acc=0.291457 val_loss=0.105516 train_loss=0.090046
# Validation loss decreased (0.107196 --> 0.105516).  Saving model ...
# [Epoch 8] val_acc=0.289474 train_acc=0.361809 val_loss=0.104049 train_loss=0.087886
# Validation loss decreased (0.105516 --> 0.104049).  Saving model ...
# EarlyStopping counter: 1 out of 30
# [Epoch 74] val_acc=0.684211 train_acc=0.934673 val_loss=0.061984 train_loss=0.046860
# EarlyStopping counter: 2 out of 30
# [Epoch 75] val_acc=0.657895 train_acc=0.929648 val_loss=0.064733 train_loss=0.046992
# EarlyStopping counter: 3 out of 30
# [Epoch 76] val_acc=0.500000 train_acc=0.904523 val_loss=0.074216 train_loss=0.047370
# EarlyStopping counter: 4 out of 30
# [Epoch 77] val_acc=0.526316 train_acc=0.924623 val_loss=0.083188 train_loss=0.046332
# EarlyStopping counter: 5 out of 30
# [Epoch 78] val_acc=0.473684 train_acc=0.934673 val_loss=0.073317 train_loss=0.047361
# EarlyStopping counter: 6 out of 30
# [Epoch 79] val_acc=0.657895 train_acc=0.934673 val_loss=0.070352 train_loss=0.044710
# EarlyStopping counter: 7 out of 30

# %%
plt.plot(train_loss_hist, label="Train Loss")
plt.plot(val_loss_hist, label="Val Loss")
plt.title("Sub1 Data Model Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(train_acc_hist, label="Train Acc")
plt.plot(val_acc_hist, label="Val Acc")
plt.title("Sub1 Data Model Accuracies")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

# %%
# Load best model and test
sub1_model = torch.load("models/resnet/sub1.pt")
sub1_model.to(DEVICE)
sub1_model.eval()
# Out:
# ResNet(
#   (initial_conv): Conv1d(22, 64, kernel_size=(7,), stride=(2,), padding=(3,))
#   (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (maxpool): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): ResidualBlock(
#     (conv1): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (layer2): ResidualBlock(
#     (conv1): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (avg_pool): AdaptiveAvgPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
# Evaluate on sub1 data
test_acc = 0
with torch.no_grad():
    for X, y in test_data[SUB1]:
        X, y = X.to(DEVICE), y.to(DEVICE)
        y_pred = sub1_model(X)
        test_acc += (y_pred.argmax(dim=1) == y.argmax(dim=1)).sum().item()
test_acc /= len(test_data[SUB1].dataset)
print("Train on sub1 data, evaluate on sub1 data")
print(f"Test Acc: {test_acc:.4f}")
# Out:
# Train on sub1 data, evaluate on sub1 data
# Test Acc: 0.7600

# %%
# Evaluate on raw data
test_acc = 0
with torch.no_grad():
    for X, y in test_data[RAW]:
        X, y = X.to(DEVICE), y.to(DEVICE)
        y_pred = sub1_model(X)
        test_acc += (y_pred.argmax(dim=1) == y.argmax(dim=1)).sum().item()
test_acc /= len(test_data[RAW].dataset)
print("Train on sub1 data, evaluate on raw data")
print(f"Test Acc: {test_acc:.4f}")
# Out:
# Train on sub1 data, evaluate on raw data
# Test Acc: 0.3725

# %% [markdown]
# ## Frequency Data

# %%
freq_model = ResNet(in_channels=22, num_classes=4)
freq_model.to(DEVICE)

optimizer = torch.optim.Adam(freq_model.parameters(), lr=0.001, weight_decay=1e-03)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)

train_loss_hist, train_acc_hist, val_loss_hist, val_acc_hist = train(
    model=freq_model,
    optimizer=optimizer,
    scheduler=scheduler,
    loss_func=nn.CrossEntropyLoss(),
    train_data=train_data[FREQ],
    val_data=valid_data[RAW],
    early_stopping_patience=30,
    cp_path="models/resnet",
    cp_filename="freq.pt",
    n_epochs=200,
    show_progress_bar=False,
)
# Out:
# Using device: cpu
# [Epoch 0] val_acc=0.257396 train_acc=0.258301 val_loss=0.025463 train_loss=0.022613
# Validation loss decreased (inf --> 0.025463).  Saving model ...
# [Epoch 1] val_acc=0.295858 train_acc=0.276871 val_loss=0.024397 train_loss=0.022055
# Validation loss decreased (0.025463 --> 0.024397).  Saving model ...
# [Epoch 2] val_acc=0.275148 train_acc=0.317389 val_loss=0.024604 train_loss=0.021708
# EarlyStopping counter: 1 out of 30
# [Epoch 3] val_acc=0.366864 train_acc=0.343275 val_loss=0.024775 train_loss=0.021186
# EarlyStopping counter: 2 out of 30
# [Epoch 4] val_acc=0.286982 train_acc=0.365785 val_loss=0.025703 train_loss=0.020996
# EarlyStopping counter: 3 out of 30
# [Epoch 5] val_acc=0.399408 train_acc=0.404052 val_loss=0.023197 train_loss=0.020596
# Validation loss decreased (0.024397 --> 0.023197).  Saving model ...
# [Epoch 6] val_acc=0.343195 train_acc=0.416995 val_loss=0.024406 train_loss=0.020425
# EarlyStopping counter: 1 out of 30
# [Epoch 7] val_acc=0.331361 train_acc=0.422060 val_loss=0.024045 train_loss=0.020341
# EarlyStopping counter: 2 out of 30
# [Epoch 8] val_acc=0.325444 train_acc=0.425999 val_loss=0.023852 train_loss=0.020214
# EarlyStopping counter: 3 out of 30
# [Epoch 9] val_acc=0.455621 train_acc=0.444007 val_loss=0.021828 train_loss=0.020086
# Validation loss decreased (0.023197 --> 0.021828).  Saving model ...
# [Epoch 10] val_acc=0.340237 train_acc=0.456387 val_loss=0.026935 train_loss=0.019761
# EarlyStopping counter: 1 out of 30
# [Epoch 11] val_acc=0.440828 train_acc=0.453573 val_loss=0.021877 train_loss=0.019551
# EarlyStopping counter: 2 out of 30
# [Epoch 12] val_acc=0.381657 train_acc=0.465954 val_loss=0.025624 train_loss=0.019466
# EarlyStopping counter: 3 out of 30
# [Epoch 13] val_acc=0.387574 train_acc=0.469893 val_loss=0.023613 train_loss=0.019401
# EarlyStopping counter: 4 out of 30
# [Epoch 14] val_acc=0.378698 train_acc=0.492403 val_loss=0.022716 train_loss=0.019301
# EarlyStopping counter: 5 out of 30
# [Epoch 15] val_acc=0.467456 train_acc=0.484524 val_loss=0.021240 train_loss=0.019142
# Validation loss decreased (0.021828 --> 0.021240).  Saving model ...
# [Epoch 16] val_acc=0.411243 train_acc=0.492966 val_loss=0.021593 train_loss=0.019029
# [Epoch 149] val_acc=0.671598 train_acc=0.799100 val_loss=0.014907 train_loss=0.012995
# EarlyStopping counter: 13 out of 30
# [Epoch 150] val_acc=0.671598 train_acc=0.792909 val_loss=0.014860 train_loss=0.012923
# EarlyStopping counter: 14 out of 30
# [Epoch 151] val_acc=0.668639 train_acc=0.806978 val_loss=0.014790 train_loss=0.012809
# EarlyStopping counter: 15 out of 30
# [Epoch 152] val_acc=0.668639 train_acc=0.802476 val_loss=0.014942 train_loss=0.012750
# EarlyStopping counter: 16 out of 30
# [Epoch 153] val_acc=0.665680 train_acc=0.797411 val_loss=0.014882 train_loss=0.012892
# EarlyStopping counter: 17 out of 30
# [Epoch 154] val_acc=0.671598 train_acc=0.814294 val_loss=0.014883 train_loss=0.012694
# EarlyStopping counter: 18 out of 30
# [Epoch 155] val_acc=0.671598 train_acc=0.799662 val_loss=0.014861 train_loss=0.012805
# EarlyStopping counter: 19 out of 30
# [Epoch 156] val_acc=0.662722 train_acc=0.797411 val_loss=0.014859 train_loss=0.012964
# EarlyStopping counter: 20 out of 30
# [Epoch 157] val_acc=0.665680 train_acc=0.800225 val_loss=0.014905 train_loss=0.012772
# EarlyStopping counter: 21 out of 30
# [Epoch 158] val_acc=0.665680 train_acc=0.814294 val_loss=0.014796 train_loss=0.012659
# EarlyStopping counter: 22 out of 30
# [Epoch 159] val_acc=0.665680 train_acc=0.804164 val_loss=0.014932 train_loss=0.012858
# EarlyStopping counter: 23 out of 30
# [Epoch 160] val_acc=0.668639 train_acc=0.812043 val_loss=0.014840 train_loss=0.012753
# EarlyStopping counter: 24 out of 30
# [Epoch 161] val_acc=0.665680 train_acc=0.820484 val_loss=0.014821 train_loss=0.012543
# EarlyStopping counter: 25 out of 30
# [Epoch 162] val_acc=0.665680 train_acc=0.813168 val_loss=0.014898 train_loss=0.012681
# EarlyStopping counter: 26 out of 30
# [Epoch 163] val_acc=0.665680 train_acc=0.808104 val_loss=0.014863 train_loss=0.012633
# EarlyStopping counter: 27 out of 30
# [Epoch 164] val_acc=0.668639 train_acc=0.813731 val_loss=0.014802 train_loss=0.012671
# EarlyStopping counter: 28 out of 30
# [Epoch 165] val_acc=0.677515 train_acc=0.801351 val_loss=0.014772 train_loss=0.012851
# EarlyStopping counter: 29 out of 30
# [Epoch 166] val_acc=0.668639 train_acc=0.812606 val_loss=0.014881 train_loss=0.012694
# EarlyStopping counter: 30 out of 30
# Early stopping.

# %%
plt.plot(train_loss_hist, label="Train Loss")
plt.plot(val_loss_hist, label="Val Loss")
plt.title("Frequency Data Model Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot(train_acc_hist, label="Train Acc")
plt.plot(val_acc_hist, label="Val Acc")
plt.title("Frequency Data Model Accuracies")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

# %%
# Load best model and test
freq_model = torch.load("models/resnet/freq.pt")
freq_model.to(DEVICE)
freq_model.eval()
# Out:
# ResNet(
#   (initial_conv): Conv1d(22, 64, kernel_size=(7,), stride=(2,), padding=(3,))
#   (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (maxpool): MaxPool1d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): ResidualBlock(
#     (conv1): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (layer2): ResidualBlock(
#     (conv1): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (avg_pool): AdaptiveAvgPool1d(output_size=1)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
# Evaluate on frequency data
test_acc = 0
with torch.no_grad():
    for X, y in test_data[RAW]:
        X, y = X.to(DEVICE), y.to(DEVICE)
        y_pred = freq_model(X)
        test_acc += (y_pred.argmax(dim=1) == y.argmax(dim=1)).sum().item()
test_acc /= len(test_data[RAW].dataset)
print("Train on frequency data, evaluate on raw data")
print(f"Test Acc: {test_acc:.4f}")
# Out:
# Train on frequency data, evaluate on raw data
# Test Acc: 0.6524

# %% [markdown]
# ## Time Series

# %%
time_slots = [50, 100, 150, 200, 250, 500, 750, 1000]

# %%
valid_acc = {}
test_acc = {}

for ts in time_slots:
    train_data, valid_data, test_data = get_time_series_dataloader(ts)
    
    time_model = ResNet(in_channels=22, num_classes=4)
    time_model.to(DEVICE)
    
    optimizer = torch.optim.Adam(time_model.parameters(), lr=0.001, weight_decay=1e-03)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
    
    _ = train(
        model=time_model,
        optimizer=optimizer,
        scheduler=scheduler,
        loss_func=nn.CrossEntropyLoss(),
        train_data=train_data,
        val_data=valid_data,
        early_stopping_patience=30,
        cp_path="models/resnet",
        cp_filename=f"time_{ts}.pt",
        n_epochs=100,
        show_progress_bar=False,
    )
    
    # Load best model and test
    time_model = torch.load(f"models/resnet/time_{ts}.pt")
    time_model.to(DEVICE)
    time_model.eval()
    
    # Evaluate validation accuracies
    valid_acc[ts] = 0
    with torch.no_grad():
        for X, y in valid_data:
            X, y = X.to(DEVICE), y.to(DEVICE)
            y_pred = time_model(X)
            valid_acc[ts] += (y_pred.argmax(dim=1) == y.argmax(dim=1)).sum().item()
    valid_acc[ts] /= len(valid_data.dataset)
    
    # Evaluate test accuracies
    test_acc[ts] = 0
    with torch.no_grad():
        for X, y in test_data:
            X, y = X.to(DEVICE), y.to(DEVICE)
            y_pred = time_model(X)
            test_acc[ts] += (y_pred.argmax(dim=1) == y.argmax(dim=1)).sum().item()
    test_acc[ts] /= len(test_data.dataset)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Using device: cpu
# [Epoch 0] val_acc=0.263314 train_acc=0.265616 val_loss=0.025063 train_loss=0.022721
# Validation loss decreased (inf --> 0.025063).  Saving model ...
# [Epoch 1] val_acc=0.292899 train_acc=0.306134 val_loss=0.024135 train_loss=0.021940
# EarlyStopping counter: 29 out of 30
# [Epoch 66] val_acc=0.532544 train_acc=0.902645 val_loss=0.019881 train_loss=0.010488
# EarlyStopping counter: 30 out of 30
# Early stopping.
# Using device: cpu
# [Epoch 0] val_acc=0.272189 train_acc=0.268993 val_loss=0.026083 train_loss=0.022399
# Validation loss decreased (inf --> 0.026083).  Saving model ...
# [Epoch 1] val_acc=0.340237 train_acc=0.302757 val_loss=0.024126 train_loss=0.021720
# Validation loss decreased (0.026083 --> 0.024126).  Saving model ...
# [Epoch 2] val_acc=0.275148 train_acc=0.338773 val_loss=0.024862 train_loss=0.021317
# EarlyStopping counter: 1 out of 30
# [Epoch 3] val_acc=0.316568 train_acc=0.391109 val_loss=0.025289 train_loss=0.020604
# EarlyStopping counter: 2 out of 30
# [Epoch 4] val_acc=0.423077 train_acc=0.435003 val_loss=0.021814 train_loss=0.020136
# Validation loss decreased (0.024126 --> 0.021814).  Saving model ...
# [Epoch 5] val_acc=0.331361 train_acc=0.455262 val_loss=0.026393 train_loss=0.019815
# EarlyStopping counter: 1 out of 30
# [Epoch 6] val_acc=0.476331 train_acc=0.480585 val_loss=0.021098 train_loss=0.019320
# Validation loss decreased (0.021814 --> 0.021098).  Saving model ...
# [Epoch 7] val_acc=0.505917 train_acc=0.504783 val_loss=0.020503 train_loss=0.018958
# Validation loss decreased (0.021098 --> 0.020503).  Saving model ...
# [Epoch 8] val_acc=0.491124 train_acc=0.513787 val_loss=0.020720 train_loss=0.018870
# EarlyStopping counter: 1 out of 30
# [Epoch 9] val_acc=0.298817 train_acc=0.528981 val_loss=0.028788 train_loss=0.018340
# EarlyStopping counter: 2 out of 30
# [Epoch 10] val_acc=0.461538 train_acc=0.539674 val_loss=0.022250 train_loss=0.018235
# EarlyStopping counter: 3 out of 30
# [Epoch 11] val_acc=0.479290 train_acc=0.558807 val_loss=0.020619 train_loss=0.017919
# EarlyStopping counter: 4 out of 30
# [Epoch 12] val_acc=0.565089 train_acc=0.572876 val_loss=0.019327 train_loss=0.017691
# Validation loss decreased (0.020503 --> 0.019327).  Saving model ...
# [Epoch 13] val_acc=0.461538 train_acc=0.576252 val_loss=0.020961 train_loss=0.017571
# EarlyStopping counter: 1 out of 30
# [Epoch 14] val_acc=0.482249 train_acc=0.595385 val_loss=0.021108 train_loss=0.017305
# EarlyStopping counter: 2 out of 30
# [Epoch 15] val_acc=0.520710 train_acc=0.599887 val_loss=0.019096 train_loss=0.017106
# Validation loss decreased (0.019327 --> 0.019096).  Saving model ...
# [Epoch 16] val_acc=0.399408 train_acc=0.621272 val_loss=0.022775 train_loss=0.016540
# EarlyStopping counter: 1 out of 30
# [Epoch 17] val_acc=0.396450 train_acc=0.612831 val_loss=0.022399 train_loss=0.016732
# EarlyStopping counter: 2 out of 30
# [Epoch 18] val_acc=0.408284 train_acc=0.638717 val_loss=0.022942 train_loss=0.016323
# EarlyStopping counter: 3 out of 30
# [Epoch 19] val_acc=0.508876 train_acc=0.629713 val_loss=0.020745 train_loss=0.016347
# [Epoch 86] val_acc=0.621302 train_acc=0.906021 val_loss=0.017686 train_loss=0.010328
# EarlyStopping counter: 23 out of 30
# [Epoch 87] val_acc=0.576923 train_acc=0.918402 val_loss=0.017599 train_loss=0.010142
# EarlyStopping counter: 24 out of 30
# [Epoch 88] val_acc=0.568047 train_acc=0.913900 val_loss=0.017598 train_loss=0.010097
# EarlyStopping counter: 25 out of 30
# [Epoch 89] val_acc=0.612426 train_acc=0.920090 val_loss=0.017308 train_loss=0.010019
# EarlyStopping counter: 26 out of 30
# [Epoch 90] val_acc=0.618343 train_acc=0.921216 val_loss=0.017250 train_loss=0.009978
# EarlyStopping counter: 27 out of 30
# [Epoch 91] val_acc=0.573964 train_acc=0.925155 val_loss=0.018237 train_loss=0.009879
# EarlyStopping counter: 28 out of 30
# [Epoch 92] val_acc=0.544379 train_acc=0.923467 val_loss=0.019154 train_loss=0.009993
# EarlyStopping counter: 29 out of 30
# [Epoch 93] val_acc=0.520710 train_acc=0.925718 val_loss=0.019100 train_loss=0.009992
# EarlyStopping counter: 30 out of 30
# Early stopping.
# Using device: cpu
# [Epoch 0] val_acc=0.245562 train_acc=0.263928 val_loss=0.025086 train_loss=0.022772
# Validation loss decreased (inf --> 0.025086).  Saving model ...
# [Epoch 1] val_acc=0.310651 train_acc=0.297130 val_loss=0.024515 train_loss=0.021959
# Validation loss decreased (0.025086 --> 0.024515).  Saving model ...
# [Epoch 2] val_acc=0.319527 train_acc=0.319077 val_loss=0.023989 train_loss=0.021618
# Validation loss decreased (0.024515 --> 0.023989).  Saving model ...
# [Epoch 3] val_acc=0.260355 train_acc=0.328081 val_loss=0.025012 train_loss=0.021346
# EarlyStopping counter: 1 out of 30
# [Epoch 4] val_acc=0.286982 train_acc=0.364660 val_loss=0.024464 train_loss=0.021027
# EarlyStopping counter: 2 out of 30
# [Epoch 5] val_acc=0.337278 train_acc=0.390546 val_loss=0.023311 train_loss=0.020586
# Validation loss decreased (0.023989 --> 0.023311).  Saving model ...
# [Epoch 6] val_acc=0.295858 train_acc=0.425999 val_loss=0.024346 train_loss=0.020265
# EarlyStopping counter: 1 out of 30
# [Epoch 7] val_acc=0.316568 train_acc=0.415307 val_loss=0.029360 train_loss=0.020303
# EarlyStopping counter: 2 out of 30
# [Epoch 8] val_acc=0.375740 train_acc=0.458638 val_loss=0.024854 train_loss=0.019691
# EarlyStopping counter: 3 out of 30
# [Epoch 9] val_acc=0.417160 train_acc=0.451885 val_loss=0.022134 train_loss=0.019705
# Validation loss decreased (0.023311 --> 0.022134).  Saving model ...
# [Epoch 10] val_acc=0.352071 train_acc=0.475521 val_loss=0.026311 train_loss=0.019533
# EarlyStopping counter: 1 out of 30
# [Epoch 11] val_acc=0.437870 train_acc=0.460889 val_loss=0.022102 train_loss=0.019370
# Validation loss decreased (0.022134 --> 0.022102).  Saving model ...
# [Epoch 12] val_acc=0.488166 train_acc=0.488464 val_loss=0.020824 train_loss=0.019198
# Validation loss decreased (0.022102 --> 0.020824).  Saving model ...
# EarlyStopping counter: 10 out of 30
# [Epoch 80] val_acc=0.520710 train_acc=0.865504 val_loss=0.020833 train_loss=0.011279
# EarlyStopping counter: 11 out of 30
# [Epoch 81] val_acc=0.511834 train_acc=0.878447 val_loss=0.021339 train_loss=0.011064
# EarlyStopping counter: 12 out of 30
# [Epoch 82] val_acc=0.585799 train_acc=0.870006 val_loss=0.018528 train_loss=0.011294
# EarlyStopping counter: 13 out of 30
# [Epoch 83] val_acc=0.514793 train_acc=0.862127 val_loss=0.021775 train_loss=0.011240
# EarlyStopping counter: 14 out of 30
# [Epoch 84] val_acc=0.579882 train_acc=0.895329 val_loss=0.018608 train_loss=0.010808
# EarlyStopping counter: 15 out of 30
# [Epoch 85] val_acc=0.526627 train_acc=0.899268 val_loss=0.019833 train_loss=0.010683
# EarlyStopping counter: 16 out of 30
# [Epoch 86] val_acc=0.476331 train_acc=0.901519 val_loss=0.024204 train_loss=0.010645
# EarlyStopping counter: 17 out of 30
# [Epoch 87] val_acc=0.505917 train_acc=0.911086 val_loss=0.022905 train_loss=0.010573
# EarlyStopping counter: 18 out of 30
# [Epoch 88] val_acc=0.600592 train_acc=0.889139 val_loss=0.017171 train_loss=0.010732
# EarlyStopping counter: 19 out of 30
# [Epoch 89] val_acc=0.565089 train_acc=0.901519 val_loss=0.018153 train_loss=0.010620
# EarlyStopping counter: 20 out of 30
# [Epoch 90] val_acc=0.579882 train_acc=0.907710 val_loss=0.018300 train_loss=0.010366
# EarlyStopping counter: 21 out of 30
# [Epoch 91] val_acc=0.559172 train_acc=0.901519 val_loss=0.018924 train_loss=0.010470
# EarlyStopping counter: 22 out of 30
# [Epoch 92] val_acc=0.582840 train_acc=0.913337 val_loss=0.018696 train_loss=0.010222
# EarlyStopping counter: 23 out of 30
# [Epoch 93] val_acc=0.576923 train_acc=0.903208 val_loss=0.018144 train_loss=0.010583
# EarlyStopping counter: 24 out of 30
# [Epoch 94] val_acc=0.526627 train_acc=0.902645 val_loss=0.018622 train_loss=0.010439
# EarlyStopping counter: 25 out of 30
# [Epoch 95] val_acc=0.579882 train_acc=0.916714 val_loss=0.018581 train_loss=0.010174
# EarlyStopping counter: 26 out of 30
# [Epoch 96] val_acc=0.556213 train_acc=0.928531 val_loss=0.018690 train_loss=0.010008
# EarlyStopping counter: 27 out of 30
# [Epoch 97] val_acc=0.491124 train_acc=0.921216 val_loss=0.024544 train_loss=0.010008
# EarlyStopping counter: 28 out of 30
# [Epoch 98] val_acc=0.579882 train_acc=0.915588 val_loss=0.017899 train_loss=0.010146
# EarlyStopping counter: 29 out of 30
# [Epoch 99] val_acc=0.594675 train_acc=0.928531 val_loss=0.017168 train_loss=0.009901
# EarlyStopping counter: 30 out of 30
# Early stopping.

# %%
plt.plot(valid_acc.keys(), valid_acc.values(), label="Valid Acc")
plt.plot(test_acc.keys(), test_acc.values(), label="Test Acc")
plt.legend()
plt.title("Time Series Model Accuracies")
plt.xlabel("Num Time Slots")
plt.ylabel("Accuracy")
plt.show()
